# %% [markdown]
# # CSCC11 - Introduction to Machine Learning, Fall 2022, Assignment 2

# %% [markdown]
# ## Authors
#
# Shawn Santhoshgeorge (1006094673) \
# Anaqi Amir Razif (1005813880)

# %% [markdown]
# ## Part 2: Programming Component

# %% [markdown]
# ### Setup

# %%
from helper import *
from NB import NB
from GCC import GCC
from KNN import KNN

# %% [markdown]
# ### Naive Bayes

# %%
X_train, y_train, X_test, y_test, labels = load_data(mode=Mode.BINARY, train_size=0.7, test_size=0.3)

n_b = NB()
n_b.train(X_train, y_train, labels)

# Using Training Dataset
y_pred_train = n_b.predict(X_train)
label_acc_train, overall_acc_train = get_accuracy(labels, y_train, y_pred_train)

# Using Testing Dataset
y_pred_test = n_b.predict(X_test)
label_acc_test, overall_acc_test = get_accuracy(labels, y_test, y_pred_test)

create_report(label_acc_train, label_acc_test, overall_acc_train, overall_acc_test)
# Out:
# <center><style type="text/css">
# #T_b1ad6 th {
#   text-align: left;
# }
# #T_b1ad6_row0_col0, #T_b1ad6_row0_col1, #T_b1ad6_row1_col0, #T_b1ad6_row1_col1, #T_b1ad6_row2_col0, #T_b1ad6_row2_col1, #T_b1ad6_row3_col0, #T_b1ad6_row3_col1, #T_b1ad6_row4_col0, #T_b1ad6_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_b1ad6" style='display:inline;'>
#   <caption>Training Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_b1ad6_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_b1ad6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b1ad6_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_b1ad6_row0_col1" class="data row0 col1" >98.86 %</td>
#     </tr>
#     <tr>
#       <td id="T_b1ad6_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_b1ad6_row1_col1" class="data row1 col1" >96.24 %</td>
#     </tr>
#     <tr>
#       <td id="T_b1ad6_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_b1ad6_row2_col1" class="data row2 col1" >95.18 %</td>
#     </tr>
#     <tr>
#       <td id="T_b1ad6_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_b1ad6_row3_col1" class="data row3 col1" >99.17 %</td>
#     </tr>
#     <tr>
#       <td id="T_b1ad6_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_b1ad6_row4_col1" class="data row4 col1" >92.88 %</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_2000e th {
#   text-align: left;
# }
# #T_2000e_row0_col0, #T_2000e_row0_col1, #T_2000e_row1_col0, #T_2000e_row1_col1, #T_2000e_row2_col0, #T_2000e_row2_col1, #T_2000e_row3_col0, #T_2000e_row3_col1, #T_2000e_row4_col0, #T_2000e_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_2000e" style='display:inline;'>
#   <caption>Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_2000e_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_2000e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2000e_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_2000e_row0_col1" class="data row0 col1" >97.47 %</td>
#     </tr>
#     <tr>
#       <td id="T_2000e_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_2000e_row1_col1" class="data row1 col1" >95.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_2000e_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_2000e_row2_col1" class="data row2 col1" >93.4 %</td>
#     </tr>
#     <tr>
#       <td id="T_2000e_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_2000e_row3_col1" class="data row3 col1" >98.67 %</td>
#     </tr>
#     <tr>
#       <td id="T_2000e_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_2000e_row4_col1" class="data row4 col1" >82.84 %</td>
#     </tr>
#   </tbody>
# </table>
# </center>
#
# <center><p>Training Overall Accuracy: 96.72 %</p><p>Testing Overall Accuracy: 93.71 %</p></center>

# %% [markdown]
# ### Gaussian Class Conditionals

# %%
X_train, y_train, X_test, y_test, labels = load_data(mode=Mode.FREQ, train_size=0.7, test_size=0.3)

g_cc = GCC()
g_cc.train(X_train, y_train, labels)

# Using Training Dataset
y_pred_train = g_cc.predict(X_train)
label_acc_train, overall_acc_train = get_accuracy(labels, y_train, y_pred_train)

# Using Testing Dataset
y_pred_test = g_cc.predict(X_test)
label_acc_test, overall_acc_test = get_accuracy(labels, y_test, y_pred_test)

create_report(label_acc_train, label_acc_test, overall_acc_train, overall_acc_test)
# Out:
# <center><style type="text/css">
# #T_c1448 th {
#   text-align: left;
# }
# #T_c1448_row0_col0, #T_c1448_row0_col1, #T_c1448_row1_col0, #T_c1448_row1_col1, #T_c1448_row2_col0, #T_c1448_row2_col1, #T_c1448_row3_col0, #T_c1448_row3_col1, #T_c1448_row4_col0, #T_c1448_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_c1448" style='display:inline;'>
#   <caption>Training Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_c1448_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_c1448_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c1448_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_c1448_row0_col1" class="data row0 col1" >100.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_c1448_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_c1448_row1_col1" class="data row1 col1" >100.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_c1448_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_c1448_row2_col1" class="data row2 col1" >100.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_c1448_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_c1448_row3_col1" class="data row3 col1" >100.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_c1448_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_c1448_row4_col1" class="data row4 col1" >100.0 %</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_b7ca6 th {
#   text-align: left;
# }
# #T_b7ca6_row0_col0, #T_b7ca6_row0_col1, #T_b7ca6_row1_col0, #T_b7ca6_row1_col1, #T_b7ca6_row2_col0, #T_b7ca6_row2_col1, #T_b7ca6_row3_col0, #T_b7ca6_row3_col1, #T_b7ca6_row4_col0, #T_b7ca6_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_b7ca6" style='display:inline;'>
#   <caption>Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_b7ca6_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_b7ca6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b7ca6_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_b7ca6_row0_col1" class="data row0 col1" >91.77 %</td>
#     </tr>
#     <tr>
#       <td id="T_b7ca6_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_b7ca6_row1_col1" class="data row1 col1" >90.83 %</td>
#     </tr>
#     <tr>
#       <td id="T_b7ca6_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_b7ca6_row2_col1" class="data row2 col1" >83.96 %</td>
#     </tr>
#     <tr>
#       <td id="T_b7ca6_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_b7ca6_row3_col1" class="data row3 col1" >96.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_b7ca6_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_b7ca6_row4_col1" class="data row4 col1" >87.31 %</td>
#     </tr>
#   </tbody>
# </table>
# </center>
#
# <center><p>Training Overall Accuracy: 100.0 %</p><p>Testing Overall Accuracy: 90.42 %</p></center>

# %% [markdown]
# ### K-Nearest Neighbours

# %%
for mode in Mode:
    display_html(f'<center> <h3> With {mode.value} Data </h3> </center>', raw=True)
    X_train, y_train, X_test, y_test, labels = load_data(mode=mode, train_size=0.7, test_size=0.3)
    for k in [1, 3, 6]:
        display_html(f'<h4> For K = {k} </h4>', raw=True)
        k_nn = KNN(k)
        k_nn.train(X_train, y_train)

        y_pred_train = k_nn.predict(X_train)
        label_acc_train, overall_acc_train = get_accuracy(labels, y_train, y_pred_train)

        y_pred_test = k_nn.predict(X_test)
        label_acc_test, overall_acc_test = get_accuracy(labels, y_test, y_pred_test)

        create_report(label_acc_train, label_acc_test, overall_acc_train, overall_acc_test)
# Out:
# <center> <h3> With Frequency Data </h3> </center>
# <h4> For K = 1 </h4>
# <center><style type="text/css">
# #T_bc673 th {
#   text-align: left;
# }
# #T_bc673_row0_col0, #T_bc673_row0_col1, #T_bc673_row1_col0, #T_bc673_row1_col1, #T_bc673_row2_col0, #T_bc673_row2_col1, #T_bc673_row3_col0, #T_bc673_row3_col1, #T_bc673_row4_col0, #T_bc673_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_bc673" style='display:inline;'>
#   <caption>Training Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_bc673_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_bc673_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bc673_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_bc673_row0_col1" class="data row0 col1" >100.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_bc673_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_bc673_row1_col1" class="data row1 col1" >100.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_bc673_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_bc673_row2_col1" class="data row2 col1" >100.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_bc673_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_bc673_row3_col1" class="data row3 col1" >100.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_bc673_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_bc673_row4_col1" class="data row4 col1" >100.0 %</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_edb74 th {
#   text-align: left;
# }
# #T_edb74_row0_col0, #T_edb74_row0_col1, #T_edb74_row1_col0, #T_edb74_row1_col1, #T_edb74_row2_col0, #T_edb74_row2_col1, #T_edb74_row3_col0, #T_edb74_row3_col1, #T_edb74_row4_col0, #T_edb74_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_edb74" style='display:inline;'>
#   <caption>Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_edb74_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_edb74_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_edb74_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_edb74_row0_col1" class="data row0 col1" >36.71 %</td>
#     </tr>
#     <tr>
#       <td id="T_edb74_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_edb74_row1_col1" class="data row1 col1" >14.17 %</td>
#     </tr>
#     <tr>
#       <td id="T_edb74_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_edb74_row2_col1" class="data row2 col1" >37.74 %</td>
#     </tr>
#     <tr>
#       <td id="T_edb74_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_edb74_row3_col1" class="data row3 col1" >38.67 %</td>
#     </tr>
#     <tr>
#       <td id="T_edb74_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_edb74_row4_col1" class="data row4 col1" >27.61 %</td>
#     </tr>
#   </tbody>
# </table>
# </center>
#
# <center><p>Training Overall Accuracy: 100.0 %</p><p>Testing Overall Accuracy: 31.44 %</p></center>
# <h4> For K = 3 </h4>
# <center><style type="text/css">
# #T_3a2a7 th {
#   text-align: left;
# }
# #T_3a2a7_row0_col0, #T_3a2a7_row0_col1, #T_3a2a7_row1_col0, #T_3a2a7_row1_col1, #T_3a2a7_row2_col0, #T_3a2a7_row2_col1, #T_3a2a7_row3_col0, #T_3a2a7_row3_col1, #T_3a2a7_row4_col0, #T_3a2a7_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_3a2a7" style='display:inline;'>
#   <caption>Training Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_3a2a7_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_3a2a7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3a2a7_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_3a2a7_row0_col1" class="data row0 col1" >67.9 %</td>
#     </tr>
#     <tr>
#       <td id="T_3a2a7_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_3a2a7_row1_col1" class="data row1 col1" >42.48 %</td>
#     </tr>
#     <tr>
#       <td id="T_3a2a7_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_3a2a7_row2_col1" class="data row2 col1" >60.77 %</td>
#     </tr>
#     <tr>
#       <td id="T_3a2a7_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_3a2a7_row3_col1" class="data row3 col1" >73.41 %</td>
#     </tr>
#     <tr>
#       <td id="T_3a2a7_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_3a2a7_row4_col1" class="data row4 col1" >50.56 %</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_35da3 th {
#   text-align: left;
# }
# #T_35da3_row0_col0, #T_35da3_row0_col1, #T_35da3_row1_col0, #T_35da3_row1_col1, #T_35da3_row2_col0, #T_35da3_row2_col1, #T_35da3_row3_col0, #T_35da3_row3_col1, #T_35da3_row4_col0, #T_35da3_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_35da3" style='display:inline;'>
#   <caption>Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_35da3_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_35da3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_35da3_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_35da3_row0_col1" class="data row0 col1" >34.18 %</td>
#     </tr>
#     <tr>
#       <td id="T_35da3_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_35da3_row1_col1" class="data row1 col1" >22.5 %</td>
#     </tr>
#     <tr>
#       <td id="T_35da3_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_35da3_row2_col1" class="data row2 col1" >31.13 %</td>
#     </tr>
#     <tr>
#       <td id="T_35da3_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_35da3_row3_col1" class="data row3 col1" >43.33 %</td>
#     </tr>
#     <tr>
#       <td id="T_35da3_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_35da3_row4_col1" class="data row4 col1" >25.37 %</td>
#     </tr>
#   </tbody>
# </table>
# </center>
#
# <center><p>Training Overall Accuracy: 60.44 %</p><p>Testing Overall Accuracy: 31.89 %</p></center>
# <h4> For K = 6 </h4>
# <center><style type="text/css">
# #T_fe277 th {
#   text-align: left;
# }
# #T_fe277_row0_col0, #T_fe277_row0_col1, #T_fe277_row1_col0, #T_fe277_row1_col1, #T_fe277_row2_col0, #T_fe277_row2_col1, #T_fe277_row3_col0, #T_fe277_row3_col1, #T_fe277_row4_col0, #T_fe277_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_fe277" style='display:inline;'>
#   <caption>Training Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_fe277_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_fe277_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fe277_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_fe277_row0_col1" class="data row0 col1" >59.66 %</td>
#     </tr>
#     <tr>
#       <td id="T_fe277_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_fe277_row1_col1" class="data row1 col1" >44.36 %</td>
#     </tr>
#     <tr>
#       <td id="T_fe277_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_fe277_row2_col1" class="data row2 col1" >55.63 %</td>
#     </tr>
#     <tr>
#       <td id="T_fe277_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_fe277_row3_col1" class="data row3 col1" >75.35 %</td>
#     </tr>
#     <tr>
#       <td id="T_fe277_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_fe277_row4_col1" class="data row4 col1" >35.58 %</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_991ec th {
#   text-align: left;
# }
# #T_991ec_row0_col0, #T_991ec_row0_col1, #T_991ec_row1_col0, #T_991ec_row1_col1, #T_991ec_row2_col0, #T_991ec_row2_col1, #T_991ec_row3_col0, #T_991ec_row3_col1, #T_991ec_row4_col0, #T_991ec_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_991ec" style='display:inline;'>
#   <caption>Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_991ec_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_991ec_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_991ec_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_991ec_row0_col1" class="data row0 col1" >31.65 %</td>
#     </tr>
#     <tr>
#       <td id="T_991ec_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_991ec_row1_col1" class="data row1 col1" >26.67 %</td>
#     </tr>
#     <tr>
#       <td id="T_991ec_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_991ec_row2_col1" class="data row2 col1" >33.96 %</td>
#     </tr>
#     <tr>
#       <td id="T_991ec_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_991ec_row3_col1" class="data row3 col1" >52.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_991ec_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_991ec_row4_col1" class="data row4 col1" >24.63 %</td>
#     </tr>
#   </tbody>
# </table>
# </center>
#
# <center><p>Training Overall Accuracy: 55.75 %</p><p>Testing Overall Accuracy: 34.28 %</p></center>
# <center> <h3> With Binary Data </h3> </center>
# <h4> For K = 1 </h4>
# <center><style type="text/css">
# #T_c340f th {
#   text-align: left;
# }
# #T_c340f_row0_col0, #T_c340f_row0_col1, #T_c340f_row1_col0, #T_c340f_row1_col1, #T_c340f_row2_col0, #T_c340f_row2_col1, #T_c340f_row3_col0, #T_c340f_row3_col1, #T_c340f_row4_col0, #T_c340f_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_c340f" style='display:inline;'>
#   <caption>Training Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_c340f_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_c340f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c340f_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_c340f_row0_col1" class="data row0 col1" >100.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_c340f_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_c340f_row1_col1" class="data row1 col1" >100.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_c340f_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_c340f_row2_col1" class="data row2 col1" >100.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_c340f_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_c340f_row3_col1" class="data row3 col1" >100.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_c340f_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_c340f_row4_col1" class="data row4 col1" >100.0 %</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_d8350 th {
#   text-align: left;
# }
# #T_d8350_row0_col0, #T_d8350_row0_col1, #T_d8350_row1_col0, #T_d8350_row1_col1, #T_d8350_row2_col0, #T_d8350_row2_col1, #T_d8350_row3_col0, #T_d8350_row3_col1, #T_d8350_row4_col0, #T_d8350_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_d8350" style='display:inline;'>
#   <caption>Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_d8350_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_d8350_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d8350_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_d8350_row0_col1" class="data row0 col1" >49.37 %</td>
#     </tr>
#     <tr>
#       <td id="T_d8350_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_d8350_row1_col1" class="data row1 col1" >31.67 %</td>
#     </tr>
#     <tr>
#       <td id="T_d8350_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_d8350_row2_col1" class="data row2 col1" >34.91 %</td>
#     </tr>
#     <tr>
#       <td id="T_d8350_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_d8350_row3_col1" class="data row3 col1" >26.67 %</td>
#     </tr>
#     <tr>
#       <td id="T_d8350_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_d8350_row4_col1" class="data row4 col1" >69.4 %</td>
#     </tr>
#   </tbody>
# </table>
# </center>
#
# <center><p>Training Overall Accuracy: 100.0 %</p><p>Testing Overall Accuracy: 42.81 %</p></center>
# <h4> For K = 3 </h4>
# <center><style type="text/css">
# #T_bfaf5 th {
#   text-align: left;
# }
# #T_bfaf5_row0_col0, #T_bfaf5_row0_col1, #T_bfaf5_row1_col0, #T_bfaf5_row1_col1, #T_bfaf5_row2_col0, #T_bfaf5_row2_col1, #T_bfaf5_row3_col0, #T_bfaf5_row3_col1, #T_bfaf5_row4_col0, #T_bfaf5_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_bfaf5" style='display:inline;'>
#   <caption>Training Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_bfaf5_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_bfaf5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bfaf5_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_bfaf5_row0_col1" class="data row0 col1" >76.14 %</td>
#     </tr>
#     <tr>
#       <td id="T_bfaf5_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_bfaf5_row1_col1" class="data row1 col1" >60.15 %</td>
#     </tr>
#     <tr>
#       <td id="T_bfaf5_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_bfaf5_row2_col1" class="data row2 col1" >67.52 %</td>
#     </tr>
#     <tr>
#       <td id="T_bfaf5_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_bfaf5_row3_col1" class="data row3 col1" >50.42 %</td>
#     </tr>
#     <tr>
#       <td id="T_bfaf5_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_bfaf5_row4_col1" class="data row4 col1" >93.63 %</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_237ff th {
#   text-align: left;
# }
# #T_237ff_row0_col0, #T_237ff_row0_col1, #T_237ff_row1_col0, #T_237ff_row1_col1, #T_237ff_row2_col0, #T_237ff_row2_col1, #T_237ff_row3_col0, #T_237ff_row3_col1, #T_237ff_row4_col0, #T_237ff_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_237ff" style='display:inline;'>
#   <caption>Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_237ff_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_237ff_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_237ff_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_237ff_row0_col1" class="data row0 col1" >53.16 %</td>
#     </tr>
#     <tr>
#       <td id="T_237ff_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_237ff_row1_col1" class="data row1 col1" >37.5 %</td>
#     </tr>
#     <tr>
#       <td id="T_237ff_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_237ff_row2_col1" class="data row2 col1" >37.74 %</td>
#     </tr>
#     <tr>
#       <td id="T_237ff_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_237ff_row3_col1" class="data row3 col1" >24.0 %</td>
#     </tr>
#     <tr>
#       <td id="T_237ff_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_237ff_row4_col1" class="data row4 col1" >73.13 %</td>
#     </tr>
#   </tbody>
# </table>
# </center>
#
# <center><p>Training Overall Accuracy: 68.72 %</p><p>Testing Overall Accuracy: 45.36 %</p></center>
# <h4> For K = 6 </h4>
# <center><style type="text/css">
# #T_482c4 th {
#   text-align: left;
# }
# #T_482c4_row0_col0, #T_482c4_row0_col1, #T_482c4_row1_col0, #T_482c4_row1_col1, #T_482c4_row2_col0, #T_482c4_row2_col1, #T_482c4_row3_col0, #T_482c4_row3_col1, #T_482c4_row4_col0, #T_482c4_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_482c4" style='display:inline;'>
#   <caption>Training Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_482c4_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_482c4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_482c4_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_482c4_row0_col1" class="data row0 col1" >74.15 %</td>
#     </tr>
#     <tr>
#       <td id="T_482c4_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_482c4_row1_col1" class="data row1 col1" >56.39 %</td>
#     </tr>
#     <tr>
#       <td id="T_482c4_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_482c4_row2_col1" class="data row2 col1" >58.84 %</td>
#     </tr>
#     <tr>
#       <td id="T_482c4_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_482c4_row3_col1" class="data row3 col1" >51.8 %</td>
#     </tr>
#     <tr>
#       <td id="T_482c4_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_482c4_row4_col1" class="data row4 col1" >74.16 %</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_59d42 th {
#   text-align: left;
# }
# #T_59d42_row0_col0, #T_59d42_row0_col1, #T_59d42_row1_col0, #T_59d42_row1_col1, #T_59d42_row2_col0, #T_59d42_row2_col1, #T_59d42_row3_col0, #T_59d42_row3_col1, #T_59d42_row4_col0, #T_59d42_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_59d42" style='display:inline;'>
#   <caption>Testing Accuracy</caption>
#   <thead>
#     <tr>
#       <th id="T_59d42_level0_col0" class="col_heading level0 col0" >Label</th>
#       <th id="T_59d42_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_59d42_row0_col0" class="data row0 col0" >business</td>
#       <td id="T_59d42_row0_col1" class="data row0 col1" >57.59 %</td>
#     </tr>
#     <tr>
#       <td id="T_59d42_row1_col0" class="data row1 col0" >entertainment</td>
#       <td id="T_59d42_row1_col1" class="data row1 col1" >30.83 %</td>
#     </tr>
#     <tr>
#       <td id="T_59d42_row2_col0" class="data row2 col0" >politics</td>
#       <td id="T_59d42_row2_col1" class="data row2 col1" >42.45 %</td>
#     </tr>
#     <tr>
#       <td id="T_59d42_row3_col0" class="data row3 col0" >sport</td>
#       <td id="T_59d42_row3_col1" class="data row3 col1" >43.33 %</td>
#     </tr>
#     <tr>
#       <td id="T_59d42_row4_col0" class="data row4 col0" >tech</td>
#       <td id="T_59d42_row4_col1" class="data row4 col1" >42.54 %</td>
#     </tr>
#   </tbody>
# </table>
# </center>
#
# <center><p>Training Overall Accuracy: 62.88 %</p><p>Testing Overall Accuracy: 44.16 %</p></center>
